# %%
import sys
sys.path.append("..")

import pickle
info = pickle.load(open("/media/ntu/volume2/s121md303_02/covid_ct/test_infos.pkl", "rb"))[0]

# %%
from utils.lmdb import LMDBImageReader, covid_ct_indexer_lung

# %%
reader = LMDBImageReader("/media/ntu/volume2/s121md303_02/covid_ct_test", covid_ct_indexer_lung)

# %%
info
# Out:
# {'index': 0,
#  'subject': 735,
#  'lung': ['/home/peter/data/covid_ct/subject_735/59851942.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851943.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851944.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851945.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851946.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851947.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851948.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851949.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851950.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851951.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851952.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851953.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851954.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851955.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851956.dcm',
#   '/home/peter/data/covid_ct/subject_735/59851957.dcm',
# ...

# %%
len(info["lung"])
# Out:
# 214
