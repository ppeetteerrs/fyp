# %%
import sys
sys.path.append("..")

import pickle
import matplotlib
from parse_data.covid_ct.create_lmdb_dataset import plot_lungs
from utils.config import config
import random

matplotlib.rcParams["animation.embed_limit"] = 2 ** 128

infos = pickle.load(open(config.COVID_19_DIR / "train_infos.pkl", "rb"))

# %%
# Good, Bad, Misaligned
plot_lungs([info for info in random.sample(infos, 10)])
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.40it/s]
