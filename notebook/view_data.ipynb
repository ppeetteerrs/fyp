# %%
import sys
sys.path.append("..")

from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import torch
from utils.img import transform
from utils.lmdb import LMDBImageDataset, covid_ct_indexer

# %%
dataset = LMDBImageDataset(Path("../input/data/covid_train"), covid_ct_indexer, transform)

# %%
raw, loc, drr, bone = dataset[270]

# %%
fig, ax = plt.subplots(1, figsize=(15,15))
ax.imshow(np.transpose(torch.concat([raw, loc, drr, bone], dim=2).numpy(), (1, 2, 0)), cmap="gray")
