# %%
# !ls -la /data/brixia | head -n 10
# Out:
# total 63963584
# drwxrwx---  2 user user   233472 Oct 16  2020 .
# drwxrwxr-x 15 user user     4096 Feb 16 16:19 ..
# -rwxrwx---  1 user user 13480322 Sep  2  2020 1000186638823204855.dcm
# -rwxrwx---  1 user user 15491196 Sep  2  2020 10003057218476364498.dcm
# -rwxrwx---  1 user user 14084658 Sep  2  2020 10005836788378209022.dcm
# -rwxrwx---  1 user user 13480322 Sep  2  2020 10011454155587105152.dcm
# -rwxrwx---  1 user user 13480474 Sep  2  2020 10015354220486554048.dcm
# -rwxrwx---  1 user user 10275168 Sep  2  2020 10026271850367430724.dcm
# -rwxrwx---  1 user user 13480470 Sep  2  2020 10027044307414466695.dcm
# ls: write error: Broken pipe

# %%
# !ls -la /data/chexpert
# Out:
# total 24556
# drwxrwxrwx     4 user user     4096 Feb  1 07:25 .
# drwxrwxr-x    15 user user     4096 Feb 16 16:19 ..
# -rwxrwxrwx     1 user user     8192 Feb  1 07:25 data.mdb
# -rwxrwxrwx     1 user user     8192 Feb  1 07:34 lock.mdb
# drwxrwxrwx 64542 user user  1916928 Oct 23  2018 train
# -rwxrwxrwx     1 user user 23165461 Jan 20  2019 train.csv
# drwxrwxrwx   202 user user     4096 Oct 19  2018 valid
# -rwxrwxrwx     1 user user    31492 Jan 20  2019 valid.csv

# %%
# !ls -la /data/covid_ct
# Out:
# total 130220
# drwxr-xr-x 1015 user user    73728 Feb  2 17:30 .
# drwxrwxr-x   15 user user     4096 Feb 16 16:19 ..
# -rw-rw-r--    1 user user 96457195 Feb  1 14:22 meta.csv
# drwxrwxr-x    2 user user    20480 Jan 20 04:08 subject_1
# drwxrwxr-x    2 user user    24576 Jan 20 04:04 subject_10
# drwxrwxr-x    2 user user    20480 Jan 20 04:03 subject_100
# drwxrwxr-x    2 user user    20480 Jan 20 04:08 subject_1000
# drwxrwxr-x    2 user user    16384 Jan 20 04:02 subject_1001
# drwxrwxr-x    2 user user    20480 Jan 20 04:00 subject_1002
# drwxrwxr-x    2 user user    20480 Jan 20 04:07 subject_1003
# drwxrwxr-x    2 user user    20480 Jan 20 04:02 subject_1004
# drwxrwxr-x    2 user user    20480 Jan 20 04:05 subject_1005
# drwxrwxr-x    2 user user    12288 Jan 20 04:08 subject_1006
# drwxrwxr-x    2 user user    16384 Jan 20 04:05 subject_1007
# drwxrwxr-x    2 user user    20480 Jan 20 04:05 subject_1008
# drwxrwxr-x    2 user user    12288 Jan 20 04:08 subject_1009
# ...

# %%
# !ls -la /data/lidc
# Out:
# total 12
# drwxrwxrwx  3 user user 4096 Feb  6 17:51 .
# drwxrwxr-x 15 user user 4096 Feb 16 16:19 ..
# drwxrwxrwx  3 user user 4096 Feb  6 17:51 manifest-1600709154662
